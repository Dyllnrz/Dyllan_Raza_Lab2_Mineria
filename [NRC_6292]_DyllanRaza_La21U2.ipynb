# %%
def imp():
  '''Llamado de librerías que permiten el uso de funciones para la ejecución
  del código'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
print(imp.__doc__)
# Out:
# Llamado de librerías que permiten el uso de funciones para la ejecución
#   del código

# %%
def dts():
  '''Lectura del dataset, esto usando separadores de ";"'''
df = pd.read_csv("data_act_01.csv",sep=";")
print(dts.__doc__)
df.head(10)
# Out:
# Lectura del dataset, esto usando separadores de ";"
#      CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0  160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1  160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2  160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3  160912801                Report  2016-03-31T00:00:00    17:38
# 4  160912811                   594  2016-03-31T00:00:00    17:42
# 5  160913003                 Ref'd  2016-03-31T00:00:00    18:29
# 6  160913050    Homeless Complaint  2016-03-31T00:00:00    18:43
# 7  160913056    Homeless Complaint  2016-03-31T00:00:00    18:47
# 8  160913078  Agg Assault / Adw Dv  2016-03-31T00:00:00    18:52
# 9  160913103            Encampment  2016-03-31T00:00:00    18:57
#
#           CallDateTime Disposition                   Address           City  \
# 0  2016-03-30T18:42:00         REP   100 Block Of Chilton Av  San Francisco
# ...

# %% [markdown]
# # Cálculo de valores nulos en el dataset

# %%
def nuls():  
  '''Calcular el número de datos nulos por cada columna'''
print(nuls.__doc__)
df.isnull().sum()
# Out:
# Calcular el número de datos nulos por cada columna
# CrimeId                      0
# OriginalCrimeTypeName        0
# OffenseDate                  0
# CallTime                     0
# CallDateTime                 0
# Disposition                  0
# Address                      0
# City                       321
# State                        3
# AgencyId                     0
# Range                    10051
# AddressType                  0
# dtype: int64

# %% [markdown]
# # Primera detección de errores del dataset
# Eliminación de columna con datos nulos en la columna "Range"

# %%
def dnuls():
  '''Eliminación de columna con datos nulos'''
df = df.drop(['Range'], axis=1)
print(dnuls.__doc__)
df
# Out:
# Eliminación de columna con datos nulos
#          CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1      160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2      160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3      160912801                Report  2016-03-31T00:00:00    17:38
# 4      160912811                   594  2016-03-31T00:00:00    17:42
# ...          ...                   ...                  ...      ...
# 10046  160964210      Well Being Check  2016-04-05T00:00:00    23:38
# 10047  160964216          Traffic Stop  2016-04-05T00:00:00    23:43
# 10048  160964227          Traffic Stop  2016-04-05T00:00:00    23:48
# 10049  160964229          Passing Call  2016-04-05T00:00:00    23:48
# 10050  160964249          Traffic Stop  2016-04-05T00:00:00    23:54
#
#               CallDateTime   Disposition                  Address  \
# ...

# %% [markdown]
# Inicialmente, el dataset cuenta con una cantidad considerable de errores o de "datos sucios" por así llamarlos. Los datos sucios son datos que contienen un formato que no es posible de usar, esto entorpeciendo la finalidad del dataset existente. En el presente dataset se encuentran diferentes tipos de datos sucios, uno de ellos son los datos nulos, teniendo así que la columna "Range" está compuesta por datos nulos totalmente. Una vez detectado el error de la columna "Range" se procede a realizar un "drop" de la columna, esto eliminándola totalmente del dataset.

# %% [markdown]
# # Segunda detección de datos erroneos
# Eliminación de datos nulos dentro de la columna "City"

# %%
def ednc():
  '''Eliminación de datos nulos en la columna "City"'''
df = df.dropna()
print(ednc.__doc__)
df
# Out:
# Eliminación de datos nulos en la columna "City"
#          CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1      160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2      160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3      160912801                Report  2016-03-31T00:00:00    17:38
# 4      160912811                   594  2016-03-31T00:00:00    17:42
# ...          ...                   ...                  ...      ...
# 10046  160964210      Well Being Check  2016-04-05T00:00:00    23:38
# 10047  160964216          Traffic Stop  2016-04-05T00:00:00    23:43
# 10048  160964227          Traffic Stop  2016-04-05T00:00:00    23:48
# 10049  160964229          Passing Call  2016-04-05T00:00:00    23:48
# 10050  160964249          Traffic Stop  2016-04-05T00:00:00    23:54
#
#               CallDateTime   Disposition                  Address  \
# ...

# %% [markdown]
# El presente dataset cuenta con dos columnas que contienen datos nulos, estas son la ya limpia columna "Range" y la columna "City". La columna "City" cuenta con datos que representan a la ciudad sobre la que se está refiriendo en el dataset. Dentro de la columna city existen hasta 6 diferentes tipos de ciudades, descontando a estas los datos nulos que entorpecen los registros del dataset. Una vez detectados los datos nulos, se procede a la realización de eliminar los datos nulos, esto con la finalidad de que no entorpezcan los demas datos existentes en el dataset

# %% [markdown]
# # Tercera detección de datos erroneos
# Reemplazo de datos incompletos dentro de la columna "City"

# %%
def gc():
  '''Detección de ciudades'''
print(gc.__doc__)
df.groupby('City').count()
# Out:
# Detección de ciudades
#                CrimeId  OriginalCrimeTypeName  OffenseDate  CallTime  \
# City
# Brisbane             1                      1            1         1
# Daly City            5                      5            5         5
# Presidio             3                      3            3         3
# SAN FRANCISCO        1                      1            1         1
# San Francisco     9665                   9665         9665      9665
# Treasure Isla       51                     51           51        51
# Yerba Buena          3                      3            3         3
#
#                CallDateTime  Disposition  Address  State  AgencyId  \
# City
# Brisbane                  1            1        1      1         1
# Daly City                 5            5        5      5         5
# Presidio                  3            3        3      3         3
# SAN FRANCISCO             1            1        1      1         1
# ...

# %%
def rdi():
  '''Reemplazo de datos incompletos existentes en la columna "City"'''
df['City'] = df['City'].replace(' S','San Francisco')
print
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1      160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2      160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3      160912801                Report  2016-03-31T00:00:00    17:38
# 4      160912811                   594  2016-03-31T00:00:00    17:42
# ...          ...                   ...                  ...      ...
# ...

# %% [markdown]
# Los datos existentes en el dataset llegan a ser variados dependiendo de la columna a la que se refiera. Dentro de la columna "City" existen hasta 6 ciudades, pero como es posible verificar en la agrupación, se muestran hasta 7, teniendo fallos en ingreso sobre San Francisco, esto sin mostrar que existe también una ciudad con un dato erroneo que solo contiene la letra "S". La letra "S" existente entre la ciudad, podría referirse a San Francisco, es por esto que se plantea el reemplazar la ciudad "S" por San Francisco. Una vez detectado el error, se usa el comando "replace", mismo que buscará la ciudad "S" y la reemplazará por "San Francisco", esto permitiendo recuperar un dato del dataset.

# %% [markdown]
# #Cuarta Detección de errores en el dataset
# Reemplazo de datos mal ingresados dentro del dataset.

# %%
def rmic():
  '''Reemplazo de ciudad mal ingresada'''
df['City'] = df['City'].replace('SAN FRANCISCO','San Francisco')
print(rmic.__doc__)
df
# Out:
# Reemplazo de ciudad mal ingresada
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1      160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2      160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3      160912801                Report  2016-03-31T00:00:00    17:38
# 4      160912811                   594  2016-03-31T00:00:00    17:42
# ...          ...                   ...                  ...      ...
# ...

# %%
def gc():
  '''Muestra de ciudad limpia'''
print(gc.__doc__)
df.groupby('City').count()
# Out:
# Muestra de ciudad limpia
#                CrimeId  OriginalCrimeTypeName  OffenseDate  CallTime  \
# City
# Brisbane             1                      1            1         1
# Daly City            5                      5            5         5
# Presidio             3                      3            3         3
# San Francisco     9666                   9666         9666      9666
# Treasure Isla       51                     51           51        51
# Yerba Buena          3                      3            3         3
#
#                CallDateTime  Disposition  Address  State  AgencyId  \
# City
# Brisbane                  1            1        1      1         1
# Daly City                 5            5        5      5         5
# Presidio                  3            3        3      3         3
# San Francisco          9666         9666     9666   9666      9666
# Treasure Isla            51           51       51     51        51
# ...

# %% [markdown]
# En la columna "City" existen 6 ciudades, mismas que cuentan con errores, un caso de esto es la ciudad "SAN FRANCISCO", esta encontrándoce con mayúsculas totales. La ciudad "San Francisco" del dataset se encuentra con mayúsculas y minúsculas, por lo que el error encontrado afecta a datos que sean de la ciudad. La limpieza del error se basa en el reemplazo de la ciudad "SAN FRANCISCO" por "San Francisco". Una vez se limpie el error, se podrá verificar dentro de la agrupación que los datos de "City" se encuentran limpios y sin errores.

# %% [markdown]
# #Quinta Detección de errores en el dataset
# Reemplazo de valores mal ingresados dentro de la columna "AgencyID".

# %%
def rva():
  '''Reemplazo de valores mal ingresados dentro de "AgencyID'''
df['AgencyId'] = df['AgencyId'].replace('CA',1)
print(rva.__doc__)
df
# Out:
# Reemplazo de valores mal ingresados dentro de "AgencyID
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          CrimeId OriginalCrimeTypeName          OffenseDate CallTime  \
# 0      160903280     Assault / Battery  2016-03-30T00:00:00    18:42
# 1      160912272    Homeless Complaint  2016-03-31T00:00:00    15:31
# 2      160912590             Susp Info  2016-03-31T00:00:00    16:49
# 3      160912801                Report  2016-03-31T00:00:00    17:38
# 4      160912811                   594  2016-03-31T00:00:00    17:42
# ...

# %% [markdown]
# #Sexta detección de errores en el dataset
# Reemplazo de datos erroneos dentro de la columna "Disposition"

# %%
def ved():
  '''Verificación de datos erroneos dentro de "Disposition"'''
print(ved.__doc__)
df['Disposition'].unique()
# Out:
# Verificación de datos erroneos dentro de "Disposition"
# array(['REP', 'GOA', 'ADV', 'HAN', 'ND', 'ARR', 'UTL', 'Not recorded',
#        'CIT', 'PAS', 'ABA', 'NOM', 'CAN', 'ADM', 'INC', 'NCR', '22',
#        'CRT', 'SFD'], dtype=object)

# %%
def red():
  '''Reemplazo de datos erroneos dentro de la columna "Disposition"'''
mode = df['Disposition'].unique()
df['Disposition']= df['Disposition'].replace('22', mode[0])
df['Disposition']= df['Disposition'].replace('Not recorded', mode[0])
df['Disposition'].unique()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# array(['REP', 'GOA', 'ADV', 'HAN', 'ND', 'ARR', 'UTL', 'CIT', 'PAS',
#        'ABA', 'NOM', 'CAN', 'ADM', 'INC', 'NCR', 'CRT', 'SFD'],
#       dtype=object)

# %% [markdown]
# Dentro de la columna "Disposition" se encuentran dos errores, estos son dos datos que fueron ingresados de manera erronea. Los datos erroneos corresponden a "22" y "Not recorded" siendo estos datos que no aportan ningún tipo de información relevante. La manera de solventar el error se muestra al insertar los datos válidos dentro del reemplazador de cada dato erroneo. Una vez ejecutado, los datos se visualizan limpios y sin errores.

# %% [markdown]
# # Inserción del dataset en un archivo de tipo JSON.

# %%
def djsn():
  '''Ingreso de datos en archivo JSON'''
df.to_json('DatasetLimpioDR.json')
